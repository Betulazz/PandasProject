# %%
import pandas as pd
import numpy as np
import os
from sqlalchemy import create_engine

os.chdir(r'C:\Users\Birchtula\PycharmProjects\PandasProject')  # 修改相对路径的位置.
# os.getcwd()

# 解决中文显示问题，下面的代码只需运行一次即可
import matplotlib as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 如果是Mac本, 不支持SimHei的时候, 可以修改为 'Microsoft YaHei' 或者 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 1.Pandas操作csv文件

# %%
# 1. 读取csv文件，获取数据
df = pd.read_csv('./data/stock_day.csv', sep=',', usecols=['open', 'high', 'close', 'low'])
df

# %%
# 2. 把读取到的数据，写到文件中
df[:10].to_csv('./data/my_file1.csv', sep=',', index=False)
print('写入成功')

# %%
# 3. 特殊的csv文件 tsv文件
# 区别：csv文件以 , 分隔  tsv以 \t 分隔
df[:10].to_csv('./data/my_file2.tsv', sep='\t', index=True)
print('写入成功')

# %%
# 4. 读取tsv文件
df2 = pd.read_csv('./data/my_file2.tsv', sep='\t', index_col=0)
df2

# %% [markdown]
# # 2. Pandas操作MySQL数据表

# %%
# 1. 准备写到MySQL数据表的数据
data = pd.read_csv('./data/csv示例文件.csv', encoding='gbk', index_col=0)
data

# %%
# 2. 导包
# from sqlalchemy import create_engine # 导入引擎对象
# 3. 创建引擎对象
# 数据库+模块名://数据库的用户名:密码@主机名:端口号/要操作的数据库名?编码方式
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/day01?charset=utf8')
# 4. 具体的往数据库写数据的动作
# append追加 replace覆盖
data.to_sql('my_table', engine, index=False, if_exists='replace')
# 5. 提示
print('写入成功')

# %%
# 6. 从SQL表中读取数据
sql_df = pd.read_sql('my_table', engine)  # 读取全表
sql_df = pd.read_sql('select name,AKA from my_table limit 0,2', engine)  # 读取表中指定数据
sql_df

# %% [markdown]
# # 3. Pandas读写json文件

# %%
# 1. 读取json文件
# 参2：读取的格式 参3：是否逐行读取
json_df = pd.read_json('./data/test.json', orient='records', lines=True)
json_df

# %%
# 2. 写入json文件中
# json_df.to_json('./data/my_file3.json',orient='records')    # 结果为[{},{},{}...]
# json_df.to_json('./data/my_file3.json') # 格式为：columns:{...}
# json_df.to_json('./data/my_file3.json',orient='index')  # 格式为：index:{...}
json_df.to_json('./data/my_file3.json', orient='records', lines=True)  #结果为 {} {} {}逐行
print('写入成功')
